# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mglearn

# %%
from sklearn.datasets import load_iris
iris=load_iris()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data[:,:2],iris.target)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((112, 2), (38, 2), (112,), (38,))

# %%
plt.subplot(2,1,1)
plt.scatter(X_train[:,0],X_train[:,1], c=y_train)
plt.subplot(2,1,2)
plt.scatter(X_test[:,0], X_test[:,1], c=y_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
y_pred
# Out:
# array([1, 0, 0, 2, 1, 0, 0, 2, 1, 2, 1, 2, 1, 2, 0, 0, 0, 2, 2, 1, 1, 1,
#        2, 1, 2, 1, 0, 1, 1, 0, 1, 1, 1, 1, 1, 2, 0, 1])

# %%
model.score(X_train, y_train)
# Out:
# 0.7946428571428571

# %%
y_test
# Out:
# array([1, 0, 0, 2, 1, 0, 0, 2, 1, 2, 1, 2, 2, 2, 0, 0, 0, 1, 2, 2, 1, 1,
#        2, 2, 2, 1, 0, 2, 2, 0, 2, 1, 1, 2, 1, 2, 0, 1])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
mglearn.plots.plot_2d_classification(model, X_train, fill=True, eps=0.5, alpha=0.4)
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)
plt.legend(loc=4)

# %%
model= KNeighborsClassifier()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
y_pred
# Out:
# array([1, 0, 0, 2, 1, 0, 0, 2, 1, 2, 1, 2, 2, 2, 0, 0, 0, 2, 2, 2, 1, 2,
#        1, 2, 2, 1, 0, 1, 1, 0, 2, 1, 1, 1, 1, 2, 0, 1])

# %%
model.score(X_train, y_train)
# Out:
# 0.8214285714285714

# %%
model=KNeighborsClassifier(1)
model.fit(X_train, y_train)
y_pred= model.predict(X_test)
y_pred
# Out:
# array([2, 0, 0, 1, 1, 0, 0, 1, 1, 1, 1, 2, 2, 2, 0, 0, 0, 2, 2, 1, 1, 2,
#        1, 1, 2, 1, 0, 1, 1, 0, 2, 1, 2, 1, 1, 2, 0, 1])

# %%
model.score(X_train, y_train)
# Out:
# 0.9553571428571429

# %%
(y_test == y_pred).mean()
# Out:
# 0.6578947368421053

# %%
model.score(X_train, y_train)
mglearn.plots.plot_2d_classification(model, X_train, fill=True, eps=0.5, alpha=0.4)
mglearn.discrete_scatter(X_test[:, 0], X_test[:,1], y_test)
plt.legend(loc=4)

# %%
model = KNeighborsClassifier(1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred
# Out:
# array([2, 0, 0, 1, 1, 0, 0, 1, 1, 1, 1, 2, 2, 2, 0, 0, 0, 2, 2, 1, 1, 2,
#        1, 1, 2, 1, 0, 1, 1, 0, 2, 1, 2, 1, 1, 2, 0, 1])

# %%
model.score(X_train, y_train)
# Out:
# 0.9464285714285714

# %%
mglearn.plots.plot_2d_classification(model, X_train, fill=True, eps=0.5, alpha=0.4)
mglearn.discrete_scatter(X_test[:, 0], X_test[:,1], y_test)
plt.legend(loc=4)

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data,iris.target)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((112, 4), (38, 4), (112,), (38,))

# %%
model=KNeighborsClassifier() 
model.fit(X_train, y_train) 
y_pred=model.predict(X_test)
y_pred
# Out:
# array([0, 1, 1, 2, 0, 1, 0, 0, 2, 2, 1, 2, 0, 0, 0, 1, 0, 2, 1, 1, 0, 0,
#        2, 1, 2, 2, 0, 0, 2, 1, 2, 0, 1, 0, 2, 1, 0, 0])

# %%
model.score(X_train, y_train) #train보다 test가 더 중요하며, 그 이유는 미래를 예측하는컴퓨터 프로그래밍특성을 따라감
# Out:
# 0.9732142857142857

# %%
model.score(X_test, y_test)
# Out:
# 0.9736842105263158
